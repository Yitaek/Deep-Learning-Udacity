# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.580671
# Nearest to known: smuggler, advance, strangle, millionaire, doubtful, sierpinski, fock, napo,
# Nearest to if: lactamase, positional, greenman, dwarf, gordon, microprocessor, strips, mosquito,
# Nearest to for: mulberry, hoarding, atherosclerosis, buckminsterfullerene, regularity, wakes, gions, quanta,
# Nearest to which: booch, aster, journey, unprovoked, coliseum, noticed, ina, vedic,
# Nearest to not: jules, cerebral, iteration, wordperfect, zaragoza, philosophiae, carrots, theologiae,
# Nearest to than: astounding, teleportation, essays, aasen, propagating, real, hermitian, briggs,
# Nearest to during: affidavit, centrale, montreux, hollywood, cynicism, macromedia, pubmed, tension,
# Nearest to some: innsbruck, thematic, expands, bolan, contextual, varying, duties, wasn,
# Nearest to but: get, wegener, premierships, gilgal, handset, auld, alva, fetishism,
# Nearest to most: mold, dumplings, leans, mans, biya, kelp, estimated, bonded,
# Nearest to by: bricklin, ambrosius, herds, stalinism, cuisine, arrests, victory, belle,
# Nearest to two: strasbourg, infrequent, procedures, lava, imaginative, disabilities, pitts, vicarage,
# Nearest to their: fatale, educator, chronometers, veto, confidently, cortex, cheng, courts,
# Nearest to also: abundances, continent, chocolates, stupa, kontor, empirical, possibilities, marija,
# Nearest to four: overt, salina, aitken, rabat, mystical, admittance, solenoid, shreck,
# Nearest to be: glorification, postalveolar, drexler, kip, opencyc, reliably, universitaire, convinced,
# Average loss at step 2000: 4.361001
# Average loss at step 4000: 3.864105
# Average loss at step 6000: 3.786006
# Average loss at step 8000: 3.687266
# Average loss at step 10000: 3.615537
# Nearest to known: such, millionaire, strangle, you, prohibits, gcd, used, well,
# Nearest to if: when, lactamase, symbolising, enhancing, hindsight, tangled, bertrand, moonraker,
# Nearest to for: gions, atherosclerosis, conductive, flute, satisfiable, where, adrift, dft,
# Nearest to which: that, it, this, and, primes, there, also, no,
# Nearest to not: it, to, camilo, often, sinless, also, they, so,
# Nearest to than: horizons, copernican, essays, astounding, teleportation, aasen, naismith, backbones,
# Nearest to during: centrale, hab, tension, burman, palaces, luminosity, maglev, affidavit,
# Nearest to some: many, risky, their, any, staffing, all, aft, this,
# Nearest to but: dalton, stele, no, firstly, checkers, maximinus, khmelnytsky, are,
# Nearest to most: mans, consistent, rapping, mercenary, grounded, tuberculosis, boneyard, firepower,
# Nearest to by: was, be, at, been, as, on, with, against,
# Nearest to two: three, five, six, eight, seven, four, nine, zero,
# Nearest to their: his, some, colonised, its, powder, bailiff, immature, blurring,
# Nearest to also: often, it, not, curving, which, chocolates, neustadt, unwritten,
# Nearest to four: six, eight, seven, three, five, nine, two, zero,
# Nearest to be: have, is, by, are, was, influences, become, were,
# Average loss at step 12000: 3.605156
# Average loss at step 14000: 3.568773
# Average loss at step 16000: 3.405086
# Average loss at step 18000: 3.454382
# Average loss at step 20000: 3.536629
# Nearest to known: such, used, gcd, millionaire, strangle, well, prohibits, regarded,
# Nearest to if: when, though, dwarf, consultants, hindsight, nipple, does, made,
# Nearest to for: by, in, of, satisfiable, where, medical, and, with,
# Nearest to which: this, that, also, who, there, it, and, but,
# Nearest to not: still, also, generally, never, it, they, formative, to,
# Nearest to than: or, horizons, copernican, fatalities, vcd, teleportation, unmatched, naismith,
# Nearest to during: centrale, hab, after, circe, cleve, entice, tension, by,
# Nearest to some: many, these, their, several, any, other, all, risky,
# Nearest to but: however, and, that, which, although, gabrielle, no, gone,
# Nearest to most: some, more, mercenary, haul, all, boneyard, rapping, jars,
# Nearest to by: be, through, been, against, for, imply, were, islets,
# Nearest to two: five, four, three, six, seven, eight, one, zero,
# Nearest to their: its, his, the, some, colonised, her, ukraine, any,
# Nearest to also: which, often, now, not, then, curving, there, still,
# Nearest to four: seven, three, six, five, eight, nine, two, zero,
# Nearest to be: have, been, by, is, was, were, become, are,
# Average loss at step 22000: 3.504378
# Average loss at step 24000: 3.490143
# Average loss at step 26000: 3.475989
# Average loss at step 28000: 3.478368
# Average loss at step 30000: 3.503169
# Nearest to known: used, well, regarded, gcd, such, millionaire, defined, cores,
# Nearest to if: when, though, fairs, skiers, hindsight, where, will, although,
# Nearest to for: medical, counterintuitive, hopeless, aridity, functors, after, with, including,
# Nearest to which: this, that, what, also, it, but, who, push,
# Nearest to not: still, they, generally, it, formative, always, often, usually,
# Nearest to than: horizons, but, vcd, fatalities, copernican, feroze, or, like,
# Nearest to during: after, when, in, at, overworld, barium, by, cleve,
# Nearest to some: many, these, several, any, their, all, other, most,
# Nearest to but: however, although, and, while, which, than, that, gabrielle,
# Nearest to most: many, more, some, mercenary, jars, idea, harm, haul,
# Nearest to by: fundamentalist, through, imply, against, was, caving, were, bags,
# Nearest to two: three, four, one, five, seven, eight, six, zero,
# Nearest to their: its, his, the, her, some, our, these, any,
# Nearest to also: often, now, still, which, there, who, sometimes, it,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to be: have, been, were, was, are, become, is, divergence,
# Average loss at step 32000: 3.500168
# Average loss at step 34000: 3.488458
# Average loss at step 36000: 3.455442
# Average loss at step 38000: 3.302000
# Average loss at step 40000: 3.427386
# Nearest to known: used, well, such, serves, regarded, defined, millionaire, gcd,
# Nearest to if: when, where, though, is, moonraker, so, lia, skiers,
# Nearest to for: stainless, in, kansai, of, crank, with, tres, when,
# Nearest to which: that, this, also, who, what, there, it, usually,
# Nearest to not: still, generally, always, they, also, usually, reconsideration, it,
# Nearest to than: or, horizons, vcd, but, feroze, fatalities, copernican, nose,
# Nearest to during: after, when, cleve, in, specially, upon, at, overworld,
# Nearest to some: many, these, any, several, other, their, most, toho,
# Nearest to but: however, although, though, and, which, really, are, before,
# Nearest to most: more, among, many, some, mercenary, haul, idea, jars,
# Nearest to by: fielding, against, with, palaces, through, imply, bresson, discrepancies,
# Nearest to two: three, four, five, seven, six, one, eight, zero,
# Nearest to their: its, his, her, the, some, these, any, our,
# Nearest to also: often, which, still, usually, now, never, sometimes, there,
# Nearest to four: six, three, seven, five, two, eight, nine, one,
# Nearest to be: have, been, is, were, was, become, create, being,
# Average loss at step 42000: 3.435900
# Average loss at step 44000: 3.455097
# Average loss at step 46000: 3.448699
# Average loss at step 48000: 3.353756
# Average loss at step 50000: 3.379975
# Nearest to known: used, regarded, such, well, serves, defined, cores, gcd,
# Nearest to if: when, where, though, could, although, after, before, will,
# Nearest to for: while, horribly, metro, tres, against, soci, sophisticated, spray,
# Nearest to which: that, this, also, who, what, often, there, usually,
# Nearest to not: still, generally, now, usually, they, always, often, actually,
# Nearest to than: or, but, vcd, feroze, much, horizons, and, fatalities,
# Nearest to during: after, when, in, at, following, while, under, specially,
# Nearest to some: many, these, several, most, both, those, their, any,
# Nearest to but: however, though, although, and, when, while, than, which,
# Nearest to most: more, some, mercenary, many, particularly, riddles, less, among,
# Nearest to by: through, was, fundamentalist, against, caving, fielding, as, during,
# Nearest to two: three, six, four, one, eight, five, seven, zero,
# Nearest to their: its, his, her, the, your, some, our, grimoires,
# Nearest to also: which, still, often, now, usually, who, never, sometimes,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to be: have, was, been, were, become, refer, is, being,
# Average loss at step 52000: 3.436296
# Average loss at step 54000: 3.425827
# Average loss at step 56000: 3.438183
# Average loss at step 58000: 3.397838
# Average loss at step 60000: 3.394563
# Nearest to known: regarded, used, serves, such, defined, well, cores, classified,
# Nearest to if: when, where, though, before, although, because, then, could,
# Nearest to for: of, including, while, without, although, if, or, after,
# Nearest to which: that, this, what, contemplate, however, who, also, it,
# Nearest to not: still, usually, now, formative, generally, never, actually, always,
# Nearest to than: or, and, but, vcd, feroze, fatalities, much, horizons,
# Nearest to during: after, in, following, when, since, before, specially, at,
# Nearest to some: many, several, these, any, most, both, this, their,
# Nearest to but: however, although, though, and, than, while, see, mechanization,
# Nearest to most: more, some, many, mercenary, riddles, use, frud, maggiore,
# Nearest to by: through, fielding, shellfish, caving, fundamentalist, against, with, islets,
# Nearest to two: three, four, six, five, one, eight, seven, zero,
# Nearest to their: its, his, her, our, the, your, some, whose,
# Nearest to also: still, often, now, sometimes, usually, which, never, always,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to be: been, become, is, have, were, are, was, refer,
# Average loss at step 62000: 3.243050
# Average loss at step 64000: 3.257849
# Average loss at step 66000: 3.403788
# Average loss at step 68000: 3.391027
# Average loss at step 70000: 3.356920
# Nearest to known: used, regarded, defined, serves, such, gcd, cores, well,
# Nearest to if: when, though, where, before, although, could, while, can,
# Nearest to for: in, including, while, to, of, if, dft, metro,
# Nearest to which: that, this, also, but, what, however, contemplate, manipulative,
# Nearest to not: now, generally, still, usually, never, always, formative, actually,
# Nearest to than: or, vcd, but, feroze, and, populous, while, joram,
# Nearest to during: after, in, following, within, since, before, when, throughout,
# Nearest to some: many, several, these, both, any, various, those, most,
# Nearest to but: however, though, although, while, which, that, than, and,
# Nearest to most: more, many, some, less, all, particularly, maggiore, mercenary,
# Nearest to by: through, in, from, bresson, be, caving, fielding, as,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to their: its, his, her, the, our, your, my, these,
# Nearest to also: still, often, now, which, sometimes, usually, never, below,
# Nearest to four: five, three, six, seven, eight, two, nine, zero,
# Nearest to be: been, become, is, were, have, being, was, are,
# Average loss at step 72000: 3.371905
# Average loss at step 74000: 3.345091
# Average loss at step 76000: 3.319927
# Average loss at step 78000: 3.351783
# Average loss at step 80000: 3.376656
# Nearest to known: used, regarded, defined, serves, such, described, called, possible,
# Nearest to if: when, though, before, although, where, then, since, can,
# Nearest to for: aac, crank, sophisticated, medical, hopeless, brabham, on, xxxv,
# Nearest to which: this, that, also, what, usually, often, actually, where,
# Nearest to not: still, generally, usually, never, now, actually, formative, they,
# Nearest to than: or, but, vcd, feroze, while, much, and, even,
# Nearest to during: after, in, following, when, before, within, throughout, although,
# Nearest to some: many, several, these, various, both, any, most, certain,
# Nearest to but: however, although, while, though, than, see, mechanization, which,
# Nearest to most: more, some, many, particularly, among, all, riddles, frud,
# Nearest to by: bags, fielding, through, UNK, when, bresson, after, soloist,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to their: its, his, her, our, your, the, my, these,
# Nearest to also: still, now, often, which, sometimes, usually, actually, never,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to be: been, become, being, have, are, were, is, easily,
# Average loss at step 82000: 3.411561
# Average loss at step 84000: 3.408249
# Average loss at step 86000: 3.390971
# Average loss at step 88000: 3.350308
# Average loss at step 90000: 3.361029
# Nearest to known: used, regarded, serves, defined, such, described, called, possible,
# Nearest to if: when, though, where, although, before, since, is, can,
# Nearest to for: of, including, after, without, carter, hopeless, while, crank,
# Nearest to which: that, also, this, what, but, both, who, actually,
# Nearest to not: still, nor, generally, now, never, actually, t, almost,
# Nearest to than: vcd, feroze, joram, or, much, even, slightly, populous,
# Nearest to during: after, in, following, within, before, although, when, throughout,
# Nearest to some: many, several, these, any, both, all, this, most,
# Nearest to but: however, although, and, though, while, which, hydrated, nevertheless,
# Nearest to most: more, some, many, particularly, immunization, use, less, all,
# Nearest to by: without, with, through, herds, after, was, fielding, using,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to their: its, his, her, our, your, my, whose, the,
# Nearest to also: still, often, now, actually, which, sometimes, usually, never,
# Nearest to four: five, seven, six, eight, three, two, nine, one,
# Nearest to be: been, become, have, being, is, was, create, sourceforge,
# Average loss at step 92000: 3.402645
# Average loss at step 94000: 3.254934
# Average loss at step 96000: 3.356892
# Average loss at step 98000: 3.246146
# Average loss at step 100000: 3.351821
# Nearest to known: defined, such, serves, used, regarded, possible, described, referred,
# Nearest to if: when, though, where, before, although, while, because, since,
# Nearest to for: after, while, including, when, without, satisfiable, sophisticated, crank,
# Nearest to which: that, this, what, actually, typically, also, usually, trilled,
# Nearest to not: never, nor, still, t, almost, now, always, generally,
# Nearest to than: or, joram, vcd, feroze, but, even, much, and,
# Nearest to during: after, in, following, before, through, when, within, throughout,
# Nearest to some: many, several, these, any, all, those, certain, various,
# Nearest to but: however, although, and, though, while, firstly, than, when,
# Nearest to most: more, less, particularly, especially, immunization, many, use, some,
# Nearest to by: when, without, through, during, fielding, bresson, against, using,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to their: its, his, her, our, your, the, my, whose,
# Nearest to also: still, now, actually, never, sometimes, often, usually, which,
# Nearest to four: six, seven, eight, five, three, two, nine, zero,
# Nearest to be: been, become, have, being, are, refer, create, carry,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# CBOW predicts word from sum of all the word vectors in its context.
# Need a window around each word 

data_index = 0

def generate_batch(batch_size, window_span):
  global data_index

  span = 2 * window_span + 1 
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(window_span)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for window_span in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=8, window_span=window_span)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 2:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
window_span = 2
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window_span * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embed, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, window_span)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.087704
# Nearest to can: hollowed, cpsu, alphabet, camilla, scarring, rossini, invariably, arabica,
# Nearest to four: lau, bulgaria, monkey, ethology, blossom, cream, scruggs, rangoon,
# Nearest to united: vermin, uppsala, staged, tla, couples, testing, heysel, capac,
# Nearest to into: humanitarian, ind, cabling, infirmities, denning, glories, callers, pleated,
# Nearest to up: doughnuts, kinderhook, euclid, indicate, festive, nagoya, aoc, psp,
# Nearest to one: amplifiers, totalitarianism, conceived, listener, tuning, hyperfine, lexington, laborers,
# Nearest to at: securely, realization, clinch, tug, restaurant, wufei, nez, deuteronomy,
# Nearest to history: carbohydrate, impeach, sseldorf, yer, confirmed, autumnal, mexico, stomachs,
# Nearest to during: median, institutionalized, corrects, doubting, tails, sto, graphite, cad,
# Nearest to people: smell, meow, haunted, nawab, parse, dip, inviting, slurred,
# Nearest to if: anthropology, wads, goodbye, zedong, evangelist, reinhardt, orkney, tornado,
# Nearest to when: salmon, fronting, tanks, paralysis, africaine, harpercollins, meredith, graviton,
# Nearest to five: ell, courtyards, imperatives, koenig, condensate, dunwich, toilet, tiffany,
# Nearest to use: yer, stamens, beatle, phages, refugees, liliales, rowland, extremists,
# Nearest to would: madrid, subsidised, akm, piercings, nellis, assoc, caso, kwazulu,
# Nearest to so: fon, isbn, boots, gbase, emerson, gough, defamation, ers,
# Average loss at step 2000: 8.012820
# Average loss at step 4000: 4.750022
# Average loss at step 6000: 3.902053
# Average loss at step 8000: 3.594074
# Average loss at step 10000: 3.550092
# Nearest to can: may, could, should, will, must, would, cannot, to,
# Nearest to four: three, five, eight, zero, seven, two, antikythera, mesolithic,
# Nearest to united: european, city, subdisciplines, aforementioned, realizes, yorke, receded, couples,
# Nearest to into: from, infirmities, expectations, affirmative, microprocessor, predefined, wes, to,
# Nearest to up: methadone, capcom, estates, format, demilitarized, readings, bowers, addressed,
# Nearest to one: laramie, four, peerages, lulu, phosphor, submarine, ryukyu, octave,
# Nearest to at: athens, calgary, means, steadfast, stampede, during, soldiers, warhol,
# Nearest to history: duress, mrna, yer, pisano, everyone, clinging, initiation, pizan,
# Nearest to during: after, in, against, at, untold, over, viewable, when,
# Nearest to people: montauban, them, individuals, areas, ubangi, mausoleum, sampo, armando,
# Nearest to if: when, fog, heliports, where, then, kournikova, temperaments, toonami,
# Nearest to when: because, until, where, if, mclaughlin, which, before, that,
# Nearest to five: four, three, eight, zero, seven, two, passy, weaknesses,
# Nearest to use: jubal, stamens, yer, universalism, correlations, laszlo, beatle, ignacio,
# Nearest to would: could, can, will, may, should, must, tumble, cannot,
# Nearest to so: ephemeral, akihabara, fon, prefers, linearly, sade, ligatures, accessibility,
# Average loss at step 12000: 3.588530
# Average loss at step 14000: 3.538883
# Average loss at step 16000: 3.503837
# Average loss at step 18000: 3.428874
# Average loss at step 20000: 3.248518
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to four: six, five, seven, eight, three, adiabats, leah, mamertines,
# Nearest to united: aforementioned, subdisciplines, bangladeshi, motala, josie, receded, arise, kes,
# Nearest to into: infirmities, notified, through, from, expectations, during, harpercollins, predefined,
# Nearest to up: down, instinctively, fruity, withheld, pollack, estates, goofy, sweeping,
# Nearest to one: resulting, cu, securing, goodness, historiae, couture, peerages, beau,
# Nearest to at: huston, when, doping, poitou, discriminated, deterministic, snapper, since,
# Nearest to history: blot, poodle, ogilvie, duress, improbable, list, durr, languages,
# Nearest to during: since, in, after, within, through, against, until, aria,
# Nearest to people: those, artists, them, alfred, bassist, cookbook, achilles, philip,
# Nearest to if: when, though, where, mortem, because, pin, however, heliports,
# Nearest to when: if, because, that, although, through, until, but, where,
# Nearest to five: six, seven, four, three, zero, eight, two, nine,
# Nearest to use: stamens, universalism, maintain, form, creation, unload, lends, monotheists,
# Nearest to would: could, will, can, may, should, must, might, did,
# Nearest to so: x, soldiers, debts, von, yer, lounge, pascal, c,
# Average loss at step 22000: 3.396529
# Average loss at step 24000: 3.318994
# Average loss at step 26000: 3.265881
# Average loss at step 28000: 3.317978
# Average loss at step 30000: 3.244182
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to four: five, joab, ch, yer, calgary, zero, br, persian,
# Nearest to united: aforementioned, indian, josie, freire, insurrections, bangladeshi, comparison, mononobe,
# Nearest to into: around, from, during, spoil, against, between, annex, notified,
# Nearest to up: down, instinctively, off, out, back, goofy, dixieland, closeness,
# Nearest to one: two, fairfield, five, indebtedness, bulgaria, alphonso, threaded, undefended,
# Nearest to at: before, creek, slurred, poitou, doping, acidosis, huston, wrought,
# Nearest to history: list, development, period, languages, improbable, spitz, blot, durr,
# Nearest to during: before, after, in, throughout, despite, against, mine, until,
# Nearest to people: members, those, men, them, countries, bassist, kang, you,
# Nearest to if: when, though, because, where, however, heliports, turnpike, until,
# Nearest to when: because, if, where, though, since, however, although, before,
# Nearest to five: four, six, zero, seven, eight, three, dress, bilabial,
# Nearest to use: terms, stamens, galilean, monotheists, pics, ime, numbers, product,
# Nearest to would: could, will, may, can, should, must, might, does,
# Nearest to so: brokers, agree, later, belfry, alves, sforza, refered, journeying,
# Average loss at step 32000: 3.063102
# Average loss at step 34000: 3.218008
# Average loss at step 36000: 3.203127
# Average loss at step 38000: 3.194484
# Average loss at step 40000: 3.178974
# Nearest to can: could, may, would, must, will, should, cannot, might,
# Nearest to four: five, six, seven, eight, three, zero, wartburg, two,
# Nearest to united: aforementioned, josie, freire, solent, bangladeshi, arise, correspondingly, pontius,
# Nearest to into: through, from, within, annex, towards, in, beyond, via,
# Nearest to up: down, off, out, instinctively, jump, them, alcott, altimeter,
# Nearest to one: suprema, rdenas, sagrada, cmos, bagpuss, cough, century, behaving,
# Nearest to at: over, before, near, huston, deterministic, in, doping, poitou,
# Nearest to history: logarithm, editions, intranet, superheroic, foster, rebadged, abernathy, veto,
# Nearest to during: before, after, in, throughout, despite, until, since, over,
# Nearest to people: men, those, members, countries, them, others, rabbinical, children,
# Nearest to if: where, when, though, because, until, since, sailboat, ve,
# Nearest to when: before, if, where, because, after, though, since, until,
# Nearest to five: four, six, eight, seven, three, zero, nine, virchow,
# Nearest to use: form, work, allow, because, terms, ido, lack, addition,
# Nearest to would: will, could, should, may, must, can, might, cannot,
# Nearest to so: brokers, agree, fact, inwards, newman, revolting, tigre, doubt,
# Average loss at step 42000: 3.237395
# Average loss at step 44000: 3.152944
# Average loss at step 46000: 3.154317
# Average loss at step 48000: 3.069206
# Average loss at step 50000: 3.072071
# Nearest to can: could, may, will, would, should, must, cannot, might,
# Nearest to four: five, three, six, two, eight, zero, seven, l,
# Nearest to united: freire, aforementioned, bangladeshi, uk, circle, solent, insurrections, member,
# Nearest to into: from, through, via, around, across, within, between, in,
# Nearest to up: off, out, back, him, profit, instinctively, altimeter, alcott,
# Nearest to one: this, reflector, fugal, collated, tg, paigc, bunk, jagiellon,
# Nearest to at: near, huston, during, quanta, in, when, solidify, until,
# Nearest to history: list, logarithm, editions, superheroic, scorers, concept, because, geography,
# Nearest to during: throughout, since, after, until, before, despite, within, in,
# Nearest to people: children, men, members, students, players, those, writers, worn,
# Nearest to if: where, when, gir, because, then, though, unto, therefore,
# Nearest to when: before, if, because, after, where, until, although, in,
# Nearest to five: six, four, three, eight, seven, zero, two, l,
# Nearest to use: cause, work, addition, monotheists, return, allow, support, used,
# Nearest to would: will, could, might, should, can, may, must, cannot,
# Nearest to so: say, thus, chanel, fact, revolting, lamentations, believe, conform,
# Average loss at step 52000: 3.111435
# Average loss at step 54000: 3.103908
# Average loss at step 56000: 2.938373
# Average loss at step 58000: 3.028132
# Average loss at step 60000: 3.070404
# Nearest to can: could, may, should, will, cannot, must, might, would,
# Nearest to four: three, seven, six, five, eight, zero, two, bridge,
# Nearest to united: member, aforementioned, josie, us, solent, hatchet, freire, spear,
# Nearest to into: through, via, towards, from, toward, beyond, notified, absorb,
# Nearest to up: off, out, down, back, instinctively, difficult, legalism, dixieland,
# Nearest to one: two, fairfield, checksum, spain, iraq, five, ponens, prodos,
# Nearest to at: near, before, gting, during, on, since, in, over,
# Nearest to history: list, course, concept, logarithm, origin, development, samara, ministry,
# Nearest to during: throughout, in, before, despite, after, until, since, following,
# Nearest to people: christians, players, languages, worn, hartley, tribes, we, members,
# Nearest to if: when, though, since, therefore, because, then, where, although,
# Nearest to when: if, before, because, although, where, then, after, also,
# Nearest to five: seven, eight, six, nine, zero, four, three, two,
# Nearest to use: allow, form, return, due, monotheists, range, create, maintain,
# Nearest to would: will, could, might, should, may, must, can, cannot,
# Nearest to so: say, fact, argued, chanel, campylobacter, believe, sometimes, indicate,
# Average loss at step 62000: 3.028874
# Average loss at step 64000: 2.932003
# Average loss at step 66000: 2.932510
# Average loss at step 68000: 2.972604
# Average loss at step 70000: 3.026133
# Nearest to can: could, cannot, may, might, must, will, would, should,
# Nearest to four: five, three, seven, six, eight, two, es, py,
# Nearest to united: u, confederate, us, solent, uk, bangladeshi, aforementioned, bracelet,
# Nearest to into: through, within, via, from, twh, across, rama, in,
# Nearest to up: off, down, difficult, together, instinctively, out, malraux, back,
# Nearest to one: two, nyi, adolescent, snare, neverwinter, fairfield, viennese, instructors,
# Nearest to at: near, during, huston, onto, in, before, doping, belizean,
# Nearest to history: origin, concept, course, list, institute, origins, festivals, development,
# Nearest to during: throughout, in, after, until, before, following, despite, since,
# Nearest to people: players, students, christians, men, person, them, children, jews,
# Nearest to if: when, though, where, because, then, although, slurred, unto,
# Nearest to when: if, before, where, because, although, after, then, while,
# Nearest to five: three, seven, six, four, eight, zero, two, prematurely,
# Nearest to use: allow, support, khartoum, ido, understand, list, addition, return,
# Nearest to would: will, might, could, can, may, should, must, cannot,
# Nearest to so: too, say, peri, aleksander, sometimes, therefore, encircled, endometrium,
# Average loss at step 72000: 2.958155
# Average loss at step 74000: 2.866867
# Average loss at step 76000: 3.007313
# Average loss at step 78000: 3.015955
# Average loss at step 80000: 2.841393
# Nearest to can: could, cannot, may, might, must, should, will, would,
# Nearest to four: five, seven, six, three, eight, zero, two, nine,
# Nearest to united: u, hatchet, confederate, josie, bracelet, aforementioned, correspondingly, solent,
# Nearest to into: through, across, within, via, jinnah, from, beyond, between,
# Nearest to up: off, down, back, together, demilitarized, out, him, closeness,
# Nearest to one: rdenas, two, behaving, peerages, svetlana, troublesome, osi, eubacteria,
# Nearest to at: near, before, huston, during, internationalism, baiting, in, gting,
# Nearest to history: origins, izz, list, pronunciation, logarithm, modern, exothermic, development,
# Nearest to during: throughout, before, after, in, until, within, since, despite,
# Nearest to people: individuals, men, residents, writers, christians, players, children, tribes,
# Nearest to if: when, though, therefore, because, so, milosevic, heliports, while,
# Nearest to when: before, because, if, where, after, although, though, thus,
# Nearest to five: four, three, seven, six, eight, zero, nine, two,
# Nearest to use: ido, allow, highlanders, lack, practice, cretians, range, share,
# Nearest to would: will, might, could, should, must, can, may, cannot,
# Nearest to so: too, say, if, therefore, sometimes, bijelo, now, capoeira,
# Average loss at step 82000: 2.946908
# Average loss at step 84000: 2.897784
# Average loss at step 86000: 2.929079
# Average loss at step 88000: 2.953396
# Average loss at step 90000: 2.834298
# Nearest to can: must, may, might, cannot, will, could, should, would,
# Nearest to four: five, six, three, eight, seven, zero, two, nine,
# Nearest to united: hatchet, confederate, us, josie, commonwealth, correspondingly, beaulieu, aforementioned,
# Nearest to into: through, across, via, from, between, within, towards, beyond,
# Nearest to up: off, back, down, out, forth, together, entrance, demilitarized,
# Nearest to one: seven, two, three, six, four, ldots, fixing, nine,
# Nearest to at: near, during, around, gliders, huston, poitou, before, anthems,
# Nearest to history: course, list, nature, usage, journal, warhol, yer, study,
# Nearest to during: throughout, after, in, before, until, since, at, despite,
# Nearest to people: players, christians, jews, writers, individuals, persons, person, children,
# Nearest to if: when, though, where, unto, because, before, thus, whether,
# Nearest to when: if, where, before, after, until, because, eventually, since,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to use: allow, because, share, ido, cretians, practice, support, monotheists,
# Nearest to would: will, could, might, must, should, may, can, cannot,
# Nearest to so: sometimes, too, say, scrip, chanel, now, campylobacter, somehow,
# Average loss at step 92000: 2.897883
# Average loss at step 94000: 2.887188
# Average loss at step 96000: 2.723040
# Average loss at step 98000: 2.469444
# Average loss at step 100000: 2.713737
# Nearest to can: might, must, could, cannot, should, may, would, will,
# Nearest to four: three, five, seven, six, eight, two, zero, nine,
# Nearest to united: confederate, member, hatchet, hansard, commonwealth, u, josie, correspondingly,
# Nearest to into: through, across, onto, from, in, beyond, throughout, down,
# Nearest to up: off, together, out, back, down, demilitarized, spinoffs, closeness,
# Nearest to one: digby, radon, tara, keeshonden, templeton, mummy, exited, differentiation,
# Nearest to at: near, during, around, huston, poitou, outside, in, cot,
# Nearest to history: course, list, origins, contemporary, literature, usage, institute, culture,
# Nearest to during: throughout, despite, after, at, until, in, over, explains,
# Nearest to people: individuals, residents, children, students, christians, players, men, jews,
# Nearest to if: when, where, though, because, however, then, pays, since,
# Nearest to when: if, where, because, although, until, before, though, presocratic,
# Nearest to five: six, four, three, eight, seven, nine, two, zero,
# Nearest to use: support, allow, practice, form, appeal, monotheists, andes, because,
# Nearest to would: will, could, might, should, must, can, cannot, did,
# Nearest to so: too, calvinists, believe, puddle, olympus, revealed, fact, sometimes,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
